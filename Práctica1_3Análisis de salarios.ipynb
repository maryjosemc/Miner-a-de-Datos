# %%
conda install -c conda-forge/label/gcc7 missingno
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import missingno as msno
# %matplotlib inline

# %%
path = 'D:\Documentos\MAC\Semestres\Octavo\Mineria de datos\Practicas\Practica1\csv\salarios.csv'
df = pd.read_csv(path, encoding='latin', error_bad_lines=False)
df.head()
# Out:
#   FUNDTYPE  DEPARTMENTCODE DEPARTMENTDESCRIPTION FUNDCODE FUNDDESCRIPTION  \
# 0    LOCAL               1   Office of the Mayor     0100  Corporate Fund
# 1    LOCAL               1   Office of the Mayor     0100  Corporate Fund
# 2    LOCAL               1   Office of the Mayor     0100  Corporate Fund
# 3    LOCAL               1   Office of the Mayor     0100  Corporate Fund
# 4    LOCAL               1   Office of the Mayor     0100  Corporate Fund
#
#    ORGANIZATIONCODE ORGANIZATIONDESCRIPTION DIVISIONCODE  DIVISIONDESCRIPTION  \
# 0              1005     Office of the Mayor         2005  Office of the Mayor
# 1              1005     Office of the Mayor         2005  Office of the Mayor
# 2              1005     Office of the Mayor         2005  Office of the Mayor
# 3              1005     Office of the Mayor         2005  Office of the Mayor
# 4              1005     Office of the Mayor         2005  Office of the Mayor
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7446 entries, 0 to 7445
# Data columns (total 22 columns):
# FUNDTYPE                   7446 non-null object
# DEPARTMENTCODE             7446 non-null int64
# DEPARTMENTDESCRIPTION      7446 non-null object
# FUNDCODE                   7446 non-null object
# FUNDDESCRIPTION            7446 non-null object
# ORGANIZATIONCODE           7446 non-null int64
# ORGANIZATIONDESCRIPTION    7446 non-null object
# DIVISIONCODE               7446 non-null object
# DIVISIONDESCRIPTION        7446 non-null object
# SECTIONCODE                7446 non-null object
# SECTIONDESCRIPTION         7446 non-null object
# SUBSECTIONCODE             7446 non-null int64
# SUBSECTIONDESCRIPTION      3779 non-null object
# SCHEDULE/GRADE             7446 non-null object
# BARGAININGUNIT             7446 non-null int64
# TITLECODE                  7446 non-null object
# TITLEDESCRIPTION           7446 non-null object
# ...

# %%
df.shape
# Out:
# (7446, 22)

# %%
df.shape[0]
# Out:
# 7446

# %%
df.shape[1]
# Out:
# 22

# %%
df.columns.values.tolist()
# Out:
# ['FUNDTYPE',
#  'DEPARTMENTCODE',
#  'DEPARTMENTDESCRIPTION',
#  'FUNDCODE',
#  'FUNDDESCRIPTION',
#  'ORGANIZATIONCODE',
#  'ORGANIZATIONDESCRIPTION',
#  'DIVISIONCODE',
#  'DIVISIONDESCRIPTION',
#  'SECTIONCODE',
#  'SECTIONDESCRIPTION',
#  'SUBSECTIONCODE',
#  'SUBSECTIONDESCRIPTION',
#  'SCHEDULE/GRADE',
#  'BARGAININGUNIT',
#  'TITLECODE',
#  'TITLEDESCRIPTION',
#  'BUDGETEDUNIT',
#  'TOTALBUDGETEDUNIT',
#  'POSITIONCONTROL',
#  'BUDGETEDPAYRATE',
#  'TOTALBUDGETEDAMOUNT']

# %%
df.dtypes
# Out:
# FUNDTYPE                    object
# DEPARTMENTCODE               int64
# DEPARTMENTDESCRIPTION       object
# FUNDCODE                    object
# FUNDDESCRIPTION             object
# ORGANIZATIONCODE             int64
# ORGANIZATIONDESCRIPTION     object
# DIVISIONCODE                object
# DIVISIONDESCRIPTION         object
# SECTIONCODE                 object
# SECTIONDESCRIPTION          object
# SUBSECTIONCODE               int64
# SUBSECTIONDESCRIPTION       object
# SCHEDULE/GRADE              object
# BARGAININGUNIT               int64
# TITLECODE                   object
# TITLEDESCRIPTION            object
# BUDGETEDUNIT                object
# TOTALBUDGETEDUNIT            int64
# POSITIONCONTROL              int64
# BUDGETEDPAYRATE            float64
# TOTALBUDGETEDAMOUNT        float64
# dtype: object

# %%
df.isnull().any().any()
# Out:
# True

# %%
msno.matrix(df)

# %%
df.replace({'': np.nan}, inplace=True)

# %%
msno.matrix(df)

# %%
msno.bar(df)

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# ['SUBSECTIONDESCRIPTION']

# %%
df.describe()
# Out:
#        DEPARTMENTCODE  ORGANIZATIONCODE  SUBSECTIONCODE  BARGAININGUNIT  \
# count     7446.000000       7446.000000     7446.000000     7446.000000
# mean        55.234220       1015.572656     2147.042036       20.680902
# std         23.473173         32.621064     2121.454333       29.410994
# min          1.000000       1005.000000        0.000000        0.000000
# 25%         38.000000       1005.000000        0.000000        1.000000
# 50%         57.000000       1005.000000     4001.000000        9.000000
# 75%         81.000000       1005.000000     4145.000000       20.000000
# max         91.000000       1155.000000     4911.000000       99.000000
#
#        TOTALBUDGETEDUNIT  POSITIONCONTROL  BUDGETEDPAYRATE  \
# count        7446.000000      7446.000000     7.446000e+03
# mean          397.334005         0.892560     8.053726e+04
# std          6542.511797         0.309693     1.830474e+05
# min             0.000000         0.000000     0.000000e+00
# ...

# %%
df.loc[[0]]
# Out:
#   FUNDTYPE  DEPARTMENTCODE DEPARTMENTDESCRIPTION FUNDCODE FUNDDESCRIPTION  \
# 0    LOCAL               1   Office of the Mayor     0100  Corporate Fund
#
#    ORGANIZATIONCODE ORGANIZATIONDESCRIPTION DIVISIONCODE  DIVISIONDESCRIPTION  \
# 0              1005     Office of the Mayor         2005  Office of the Mayor
#
#   SECTIONCODE  ... SUBSECTIONDESCRIPTION  SCHEDULE/GRADE BARGAININGUNIT  \
# 0        3005  ...                   NaN            1 00              9
#
#   TITLECODE  TITLEDESCRIPTION BUDGETEDUNIT TOTALBUDGETEDUNIT POSITIONCONTROL  \
# 0      9901             Mayor       Annual                 1               1
#
#    BUDGETEDPAYRATE  TOTALBUDGETEDAMOUNT
# 0         216210.0             216210.0
#
# [1 rows x 22 columns]

# %%
df.loc[30:33]
# Out:
#    FUNDTYPE  DEPARTMENTCODE DEPARTMENTDESCRIPTION FUNDCODE FUNDDESCRIPTION  \
# 30    LOCAL               1   Office of the Mayor     0100  Corporate Fund
# 31    LOCAL               1   Office of the Mayor     0100  Corporate Fund
# 32    LOCAL               1   Office of the Mayor     0100  Corporate Fund
# 33    LOCAL               1   Office of the Mayor     0100  Corporate Fund
#
#     ORGANIZATIONCODE ORGANIZATIONDESCRIPTION DIVISIONCODE  \
# 30              1005     Office of the Mayor         2005
# 31              1005     Office of the Mayor         2005
# 32              1005     Office of the Mayor         2005
# 33              1005     Office of the Mayor         2005
#
#     DIVISIONDESCRIPTION SECTIONCODE  ... SUBSECTIONDESCRIPTION  \
# 30  Office of the Mayor        3010  ...                   NaN
# 31  Office of the Mayor        3010  ...                   NaN
# 32  Office of the Mayor        3010  ...                   NaN
# ...

# %%
df.drop([0,24,51], axis=0).head()
# Out:
#   FUNDTYPE  DEPARTMENTCODE DEPARTMENTDESCRIPTION FUNDCODE FUNDDESCRIPTION  \
# 1    LOCAL               1   Office of the Mayor     0100  Corporate Fund
# 2    LOCAL               1   Office of the Mayor     0100  Corporate Fund
# 3    LOCAL               1   Office of the Mayor     0100  Corporate Fund
# 4    LOCAL               1   Office of the Mayor     0100  Corporate Fund
# 5    LOCAL               1   Office of the Mayor     0100  Corporate Fund
#
#    ORGANIZATIONCODE ORGANIZATIONDESCRIPTION DIVISIONCODE  DIVISIONDESCRIPTION  \
# 1              1005     Office of the Mayor         2005  Office of the Mayor
# 2              1005     Office of the Mayor         2005  Office of the Mayor
# 3              1005     Office of the Mayor         2005  Office of the Mayor
# 4              1005     Office of the Mayor         2005  Office of the Mayor
# 5              1005     Office of the Mayor         2005  Office of the Mayor
#
# ...

# %%
df.drop(df.index[1:5], axis=0).head(5)
# Out:
#   FUNDTYPE  DEPARTMENTCODE DEPARTMENTDESCRIPTION FUNDCODE FUNDDESCRIPTION  \
# 0    LOCAL               1   Office of the Mayor     0100  Corporate Fund
# 5    LOCAL               1   Office of the Mayor     0100  Corporate Fund
# 6    LOCAL               1   Office of the Mayor     0100  Corporate Fund
# 7    LOCAL               1   Office of the Mayor     0100  Corporate Fund
# 8    LOCAL               1   Office of the Mayor     0100  Corporate Fund
#
#    ORGANIZATIONCODE ORGANIZATIONDESCRIPTION DIVISIONCODE  DIVISIONDESCRIPTION  \
# 0              1005     Office of the Mayor         2005  Office of the Mayor
# 5              1005     Office of the Mayor         2005  Office of the Mayor
# 6              1005     Office of the Mayor         2005  Office of the Mayor
# 7              1005     Office of the Mayor         2005  Office of the Mayor
# 8              1005     Office of the Mayor         2005  Office of the Mayor
#
# ...

# %%
df[100:].head() #df.tail(-100) )
# Out:
#     FUNDTYPE  DEPARTMENTCODE        DEPARTMENTDESCRIPTION FUNDCODE  \
# 100    LOCAL               3  Office of Inspector General     0100
# 101    LOCAL               3  Office of Inspector General     0100
# 102    LOCAL               3  Office of Inspector General     0100
# 103    LOCAL               3  Office of Inspector General     0100
# 104    LOCAL               3  Office of Inspector General     0100
#
#     FUNDDESCRIPTION  ORGANIZATIONCODE      ORGANIZATIONDESCRIPTION  \
# 100  Corporate Fund              1005  Office of Inspector General
# 101  Corporate Fund              1005  Office of Inspector General
# 102  Corporate Fund              1005  Office of Inspector General
# 103  Corporate Fund              1005  Office of Inspector General
# 104  Corporate Fund              1005  Office of Inspector General
#
#     DIVISIONCODE          DIVISIONDESCRIPTION SECTIONCODE  ...  \
# 100         2005  Office of Inspector General        3020  ...
# ...

# %%
df.TOTALBUDGETEDAMOUNT.values
# Out:
# array([216210.,  74208.,  58752., ..., 151560., 928938.,  17148.])

# %%
df['TOTALBUDGETEDAMOUNT'].values
# Out:
# array([216210.,  74208.,  58752., ..., 151560., 928938.,  17148.])

# %%
df.TOTALBUDGETEDAMOUNT.unique()
# Out:
# array([216210.,  74208.,  58752., ..., 151560., 928938.,  17148.])

# %%
df.TOTALBUDGETEDAMOUNT.value_counts()
# Out:
# 88044.0     97
# 73104.0     95
# 80232.0     89
# 96564.0     77
# 96096.0     77
#             ..
# 114672.0     1
# 10007.0      1
# 34008.0      1
# 229692.0     1
# 1680.0       1
# Name: TOTALBUDGETEDAMOUNT, Length: 2864, dtype: int64

# %%
df.agg(['count', 'size', 'nunique'])
# Out:
#          FUNDTYPE  DEPARTMENTCODE  DEPARTMENTDESCRIPTION  FUNDCODE  \
# count        7446            7446                   7446      7446
# size         7446            7446                   7446      7446
# nunique         3              36                     36        80
#
#          FUNDDESCRIPTION  ORGANIZATIONCODE  ORGANIZATIONDESCRIPTION  \
# count               7446              7446                     7446
# size                7446              7446                     7446
# nunique               78                19                       55
#
#          DIVISIONCODE  DIVISIONDESCRIPTION  SECTIONCODE  ...  \
# count            7446                 7446         7446  ...
# size             7446                 7446         7446  ...
# nunique           106                  161          282  ...
#
#          SUBSECTIONDESCRIPTION  SCHEDULE/GRADE  BARGAININGUNIT  TITLECODE  \
# count                     3779            7446            7446       7446
# ...

# %%
df.groupby('TITLECODE').agg(['count', 'size', 'nunique']).stack()
# Out:
#                    FUNDTYPE  DEPARTMENTCODE  DEPARTMENTDESCRIPTION  FUNDCODE  \
# TITLECODE
# 0011      count          34              34                     34        34
#           size           34              34                     34        34
#           nunique         3               7                      7        12
# 0012      count         104             104                    104       104
#           size          104             104                    104       104
# ...                     ...             ...                    ...       ...
# 9988      size            1               1                      1         1
#           nunique         1               1                      1         1
# 9991      count           1               1                      1         1
#           size            1               1                      1         1
#           nunique         1               1                      1         1
#
# ...

# %%
df.groupby('TITLECODE').agg(['count', 'size', 'nunique'])
# Out:
#           FUNDTYPE              DEPARTMENTCODE               \
#              count size nunique          count size nunique
# TITLECODE
# 0011            34   34       3             34   34       7
# 0012           104  104       2            104  104      12
# 0015           476  476       3            476  476      32
# 0044           100  100       2            100  100      19
# 0101            11   11       2             11   11       4
# ...            ...  ...     ...            ...  ...     ...
# 9981             1    1       1              1    1       1
# 9984             1    1       1              1    1       1
# 9985             1    1       1              1    1       1
# 9988             1    1       1              1    1       1
# 9991             1    1       1              1    1       1
#
#           DEPARTMENTDESCRIPTION              FUNDCODE  ... TOTALBUDGETEDUNIT  \
#                           count size nunique    count  ...           nunique
# ...

# %%
df_dropped = df.dropna(subset=['ORGANIZATIONCODE'])
df_dropped.head()
# Out:
#   FUNDTYPE  DEPARTMENTCODE DEPARTMENTDESCRIPTION FUNDCODE FUNDDESCRIPTION  \
# 0    LOCAL               1   Office of the Mayor     0100  Corporate Fund
# 1    LOCAL               1   Office of the Mayor     0100  Corporate Fund
# 2    LOCAL               1   Office of the Mayor     0100  Corporate Fund
# 3    LOCAL               1   Office of the Mayor     0100  Corporate Fund
# 4    LOCAL               1   Office of the Mayor     0100  Corporate Fund
#
#    ORGANIZATIONCODE ORGANIZATIONDESCRIPTION DIVISIONCODE  DIVISIONDESCRIPTION  \
# 0              1005     Office of the Mayor         2005  Office of the Mayor
# 1              1005     Office of the Mayor         2005  Office of the Mayor
# 2              1005     Office of the Mayor         2005  Office of the Mayor
# 3              1005     Office of the Mayor         2005  Office of the Mayor
# 4              1005     Office of the Mayor         2005  Office of the Mayor
#
# ...

# %%
df_dropped.shape
# Out:
# (7446, 22)

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#   FUNDTYPE  DEPARTMENTCODE DEPARTMENTDESCRIPTION FUNDCODE FUNDDESCRIPTION  \
# 0    LOCAL               1   Office of the Mayor     0100  Corporate Fund
# 1    LOCAL               1   Office of the Mayor     0100  Corporate Fund
# 2    LOCAL               1   Office of the Mayor     0100  Corporate Fund
# 3    LOCAL               1   Office of the Mayor     0100  Corporate Fund
# 4    LOCAL               1   Office of the Mayor     0100  Corporate Fund
#
#    ORGANIZATIONCODE ORGANIZATIONDESCRIPTION DIVISIONCODE  DIVISIONDESCRIPTION  \
# 0              1005     Office of the Mayor         2005  Office of the Mayor
# 1              1005     Office of the Mayor         2005  Office of the Mayor
# 2              1005     Office of the Mayor         2005  Office of the Mayor
# 3              1005     Office of the Mayor         2005  Office of the Mayor
# 4              1005     Office of the Mayor         2005  Office of the Mayor
#
# ...

# %%
df_copy.shape
# Out:
# (7446, 22)

# %%
df_dropped['BUDGETEDPAYRATE'].dtype
# Out:
# dtype('float64')

# %%
df_copy['BUDGETEDPAYRATE'].fillna(value=np.round(df['BUDGETEDPAYRATE'].mean(),decimals=0), inplace=True)

# %%
df_copy.agg(['count', 'size', 'nunique'])
# Out:
#          FUNDTYPE  DEPARTMENTCODE  DEPARTMENTDESCRIPTION  FUNDCODE  \
# count        7446            7446                   7446      7446
# size         7446            7446                   7446      7446
# nunique         3              36                     36        80
#
#          FUNDDESCRIPTION  ORGANIZATIONCODE  ORGANIZATIONDESCRIPTION  \
# count               7446              7446                     7446
# size                7446              7446                     7446
# nunique               78                19                       55
#
#          DIVISIONCODE  DIVISIONDESCRIPTION  SECTIONCODE  ...  \
# count            7446                 7446         7446  ...
# size             7446                 7446         7446  ...
# nunique           106                  161          282  ...
#
#          SUBSECTIONDESCRIPTION  SCHEDULE/GRADE  BARGAININGUNIT  TITLECODE  \
# count                     3779            7446            7446       7446
# ...

# %%
list(df['SECTIONDESCRIPTION'].unique())
# Out:
# ['Executive',
#  'Administrative',
#  'Office of the Press Secretary',
#  'Legislative Counsel and Government Affairs',
#  'Office of Violence Prevention',
#  'Operations',
#  'Legal',
#  'Investigations',
#  'Audit and Program Review',
#  'Public Safety Audit',
#  'Administration',
#  'Revenue and Expenditure Analysis',
#  'City Council',
#  'Management Initiatives',
#  'Compensation Control',
#  'Capital / Motor Fuel Tax Administration',
#  'Data Analytics',
#  'Office of the Chief Information Officer',
#  'Finance and Administration',
#  'Planning Policy and Management',
#  'Enterprise Architecture',
#  'Enterprise Financial and HR Systems',
#  'Enterprise Inspections and Permitting',
#  'Enterprise Revenue and Tax',
#  'Enterprise CSW Management',
#  'Enterprise Health and Human Services Systems',
#  'Technical Operations',
#  'Network and Telecommunications',
#  'Data Center Operations',
#  'Information Security Office',
#  'Data Science Office',
#  'Software Development',
# ...

# %%
list(df['SUBSECTIONDESCRIPTION'].unique())
# Out:
# [nan,
#  'General Accounting',
#  'Reconciliation',
#  'Cost Control',
#  'Administrative Services',
#  'Public Safety and Planning',
#  'Systems Audit and Schedules',
#  'DFSS Accounting',
#  'Community Development Accounting',
#  'Transportation Accounting',
#  'Health',
#  'Voucher / Audit',
#  'Financial Policy',
#  'Employee Benefits Management',
#  'Risk Management',
#  'Cash Management and Disbursements',
#  'Payroll Systems and Operations',
#  'Cashiering',
#  'Tax Administration',
#  'Tax Enforcement',
#  'Parking Enforcement',
#  'Booting',
#  'Enforcement Administration',
#  'Field Support',
#  'Permits',
#  'Advanced Collections',
#  'Citation Administration',
#  'Administration',
#  'Support Services',
#  'Financial/Personnel/Payroll Management',
#  'Customer Services',
#  'Building Hearings Division',
#  'Consumer and Environmental Division',
#  'Municipal Hearings Division',
#  'Vehicle Hearings Division',
#  "Corporation Counsel's Office",
#  'Corporate Torts',
# ...

# %%
df_copy['TOTALBUDGETEDUNIT'].mean()
# Out:
# 397.3340048348106

# %%
df_copy.groupby(["ORGANIZATIONDESCRIPTION", "DIVISIONDESCRIPTION", "SECTIONDESCRIPTION"]).count()
# Out:
#                                                                                                                                      FUNDTYPE  \
# ORGANIZATIONDESCRIPTION         DIVISIONDESCRIPTION                               SECTIONDESCRIPTION
# Board of Election Commissioners Election and Administration Division              Administration                                           14
#                                                                                   Community Services and Deputy Registrars                 15
#                                                                                   Election Support                                         27
#                                                                                   Electronic Voting Systems                                 9
#                                                                                   Voter Records and Data Processing                        21
# ...

# %%
df_copy.SECTIONDESCRIPTION
# Out:
# 0              Executive
# 1              Executive
# 2              Executive
# 3              Executive
# 4         Administrative
#               ...
# 7441    Code Enforcement
# 7442    Code Enforcement
# 7443    Code Enforcement
# 7444    Code Enforcement
# 7445    Code Enforcement
# Name: SECTIONDESCRIPTION, Length: 7446, dtype: object

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#      FUNDTYPE  DEPARTMENTCODE                        DEPARTMENTDESCRIPTION  \
# 1224    LOCAL              38  Department of Fleet and Facility Management
# 724     LOCAL              30        Department of Administrative Hearings
# 2746    LOCAL              57                    Chicago Police Department
# 4400    LOCAL              88               Department of Water Management
# 7435     CDBG              67                      Department of Buildings
#
#      FUNDCODE                             FUNDDESCRIPTION  ORGANIZATIONCODE  \
# 1224     0100                              Corporate Fund              1005
# 724      0100                              Corporate Fund              1005
# 2746     0100                              Corporate Fund              1005
# 4400     0200                                  Water Fund              1015
# 7435     0J45  Community Development Block Grant Year XLV              1005
#
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

# %%
plt.hist(df_sample['SECTIONDESCRIPTION'])
plt.xlabel('SECTIONDESCRIPTION')
plt.ylabel('Frequency')
plt.title('Frequency of SECTIONDESCRIPTION')
# Out:
# Text(0.5, 1.0, 'Frequency of SECTIONDESCRIPTION')
